# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import sys
sys.path.append('/content/gdrive/My Drive/Colab Notebooks/practice/face_mask_detection_yolov3')

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.5.0+cu101 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
# !ls /content/gdrive/My\ Drive/Colab\ Notebooks/practice/face_mask_detection_yolov3/*
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/practice/face_mask_detection_yolov3/yolov3_assignment13.ipynb'
#
# '/content/gdrive/My Drive/Colab Notebooks/practice/face_mask_detection_yolov3/yolov3':
#  annotation_tool	 output         runs		  'ubdivisions=1'
#  cfg			 __pycache__    test_batch0.png    utils
#  data			 README.md      test.py		   vim.exe.stackdump
#  detect.py		 results.json   ting		   weights
#  image_from_video_trim	 results.png    train_batch0.png
#  models.py		 results.txt    train.py

# %%
cd /content/gdrive/My\ Drive/Colab\ Notebooks/practice/face_mask_detection_yolov3/yolov3/
# Out:
# /content/gdrive/My Drive/Colab Notebooks/practice/face_mask_detection_yolov3/yolov3

# %%
# !ls
# Out:
#  annotation_tool	 output         runs		  'ubdivisions=1'
#  cfg			 __pycache__    test_batch0.png    utils
#  data			 README.md      test.py		   vim.exe.stackdump
#  detect.py		 results.json   ting		   weights
#  image_from_video_trim	 results.png    train_batch0.png
#  models.py		 results.txt    train.py

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-05-23 11:42:30.812135: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (443 found, 0 missing, 1 empty, 0 duplicate, for 444 images): 100% 444/444 [03:02<00:00,  2.44it/s]
# Caching images (0.2GB): 100% 444/444 [03:07<00:00,  2.36it/s]
# Reading image shapes: 100% 49/49 [00:18<00:00,  2.59it/s]
# ...

# %%
# !python detect.py --conf-thres 0.1 --output out_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# image 1/493 data/customdata/images/img0.jpg: 512x512 1 face masks, Done. (0.019s)
# image 2/493 data/customdata/images/img1.jpg: 384x512 1 face masks, Done. (0.016s)
# image 3/493 data/customdata/images/img10.jpg: 384x512 1 face masks, Done. (0.016s)
# image 4/493 data/customdata/images/img100.jpg: 320x512 2 face masks, Done. (0.015s)
# image 5/493 data/customdata/images/img101.jpg: 384x512 2 face masks, Done. (0.016s)
# ...

# %%
Image(filename='out_out/img34.jpg', width=600)

# %%
Image(filename='out_out/img201.jpg', width=600)

# %%
Image(filename='out_out/img350.jpg', width=600)

# %%
# !python detect.py --conf-thres 0.1 --source /content/gdrive/My\ Drive/Colab\ Notebooks/practice/face_mask_detection_yolov3/yolov3/image_from_video --output mask_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='mask_out', save_txt=False, source='/content/gdrive/My Drive/Colab Notebooks/practice/face_mask_detection_yolov3/yolov3/image_from_video', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# image 1/1202 /content/gdrive/My Drive/Colab Notebooks/practice/face_mask_detection_yolov3/yolov3/image_from_video/image-001.png: 320x512 Done. (0.016s)
# image 2/1202 /content/gdrive/My Drive/Colab Notebooks/practice/face_mask_detection_yolov3/yolov3/image_from_video/image-002.png: 320x512 Done. (0.016s)
# ...

# %%
Image(filename='mask_out/image-888.png', width=600)
